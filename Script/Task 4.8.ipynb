# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing Dataframe

# %%
ords_prods_merge= pd.read_pickle ('..\Prepared Data\orders_products_merged_updated_again.pkl')

# %% [markdown]
# ### Step 2

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Step 3

# %% [markdown]
# The complete dataframe reveals all department IDs, while the subset shows disparity in means when comparing outcomes of each aggregation.

# %% [markdown]
# ### Step 4

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### Step 5

# %%
# group by prices
ords_prods_merge.groupby('prices')

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer    10.388747
# New customer      13.294370
# Regular customer  12.496203

# %% [markdown]
# ### Step 6

# %%
# group by mean
ords_prods_merge['mean_order'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['mean_order'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_order'] >= 10, 'spending_flag'] = 'high spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31798751
# high spender      635461
# Name: spending_flag, dtype: int64

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# ...

# %% [markdown]
# ### step 7

# %%
# group by median
ords_prods_merge['median_ordering'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['median_ordering'] > 20, 'prior_ordering_flag'] = 'non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_ordering'] > 10) & (ords_prods_merge['median_ordering'] <= 20), 'prior_ordering_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_ordering'] <= 10, 'prior_ordering_flag'] = 'Frequent customer'

# %%
ords_prods_merge['prior_ordering_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21577409
# Regular customer          7217134
# non-frequent customer     3639669
# Name: prior_ordering_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'prior_ordering_flag', 'median_ordering']].head(60)
# Out:
#     user_id    prior_ordering_flag  median_ordering
# 0         1  non-frequent customer             20.5
# 1         1  non-frequent customer             20.5
# 2         1  non-frequent customer             20.5
# 3         1  non-frequent customer             20.5
# 4         1  non-frequent customer             20.5
# 5         1  non-frequent customer             20.5
# 6         1  non-frequent customer             20.5
# 7         1  non-frequent customer             20.5
# 8         1  non-frequent customer             20.5
# 9         1  non-frequent customer             20.5
# 10       15      Frequent customer             10.0
# 11       15      Frequent customer             10.0
# 12       15      Frequent customer             10.0
# 13       15      Frequent customer             10.0
# 14       15      Frequent customer             10.0
# 15       19      Frequent customer              6.0
# 16       19      Frequent customer              6.0
# ...

# %% [markdown]
# ## Exporting Dataframe

# %%
ords_prods_merge.to_pickle('..\Prepared Data\orders_products_merged_updated_again_2.pkl')
